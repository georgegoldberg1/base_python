# %% [markdown]
# Run this notebook the first time you load Jupyter.
#
# You want to save these versions after creating your app, to preserve it when future package versions could break it.
#
# You can then specify the versions in your requirements.txt file in future, to lock this working version of your app.

# %%
pip freeze
# Out:
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# attrs==21.4.0
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==5.0.0
# blinker==1.4
# certifi==2022.5.18.1
# cffi==1.15.0
# charset-normalizer==2.0.12
# cramjam==2.5.0
# cryptography==3.4.8
# cycler==0.11.0
# dbus-python==1.2.18
# debugpy==1.6.0
# decorator==5.1.1
# defusedxml==0.7.1
# distro==1.7.0
# distro-info===1.1build1
# entrypoints==0.4
# executing==0.8.3
# fastjsonschema==2.15.3
# fastparquet==0.8.1
# fonttools==4.33.3
# fsspec==2022.5.0
# httplib2==0.20.2
# idna==3.3
# importlib-metadata==4.6.4
# ipykernel==6.13.1
# ipython==8.4.0
# ipython-genutils==0.2.0
# ipywidgets==7.7.0
# jedi==0.18.1
# jeepney==0.7.1
# Jinja2==3.1.2
# joblib==1.1.0
# jsonschema==4.6.0
# jupyter==1.0.0
# jupyter-client==7.3.4
# jupyter-console==6.4.3
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.10.0
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# ...
